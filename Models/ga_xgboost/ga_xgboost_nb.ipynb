# %%
# Clone repo into Colab VM (replace with your repo URL)
from getpass import getpass
token = getpass("GitHub token: ")
import os
if os.path.exists("/content/CynolycusBot/.git"):
    # %cd /content/CynolycusBot
    # !git pull
else:
    # !git clone https://{token}@github.com/ThompsonLuke7/CynolycusBot.git /content/CynolycusBot
    # %cd /content/CynolycusBot
    # !git remote set-url origin https://{token}@github.com/ThompsonLuke7/CynolycusBot.git

# !git config user.name "thompsonluke7"
# !git config user.email "lukethompson2203@gmail.com"
# Out:
# /content/CynolycusBot
# Already up to date.

# %%
# %cd /content/CynolycusBot
# %run Models/ga_xgboost/ga_xgboost_two_models_test.py
# Out:
# /content/CynolycusBot
# Loaded train split: (920, 1224)
# Loaded test split:  (80, 1224)
#
# === LONG side ===
# LONG train positives: 75, negatives: 845, scale_pos_weight: 11.27
# [GA-XGB] Generation 1/30 - best val acc: 0.7500, global best: 0.7500
# [GA-XGB] Generation 2/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 3/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 4/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 5/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 6/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 7/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 8/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 9/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 10/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 11/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 12/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 13/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 14/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 15/30 - best val acc: 0.6000, global best: 0.8571
# [GA-XGB] Generation 16/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 17/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 18/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 19/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 20/30 - best val acc: 0.7500, global best: 0.8571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/CynolycusBot/Models/ga_xgboost/ga_xgboost_two_models_test.py in <module>
#     141 # Train both models
#     142 # ------------------------------
# --> 143 long_selector = train_and_eval_side(y_long_train, y_long_test, "LONG")
#     144 short_selector = train_and_eval_side(y_short_train, y_short_test, "SHORT")
#     145
#
# /content/CynolycusBot/Models/ga_xgboost/ga_xgboost_two_models_test.py in train_and_eval_side(y_train, y_test, side_name)
#     121
#     122     # GA + XGB training on this side
# --> 123     selector.fit(X_train, y_train)
#     124
#     125     print(f"{side_name} best GA val F1:", selector.best_score_)
#
# /content/CynolycusBot/Models/ga_xgboost/ga_xgboost.py in fit(self, X, y)
#      76             # Evaluate fitness (validation accuracy) of each chromosome
#      77             for i, mask in enumerate(population):
# ---> 78                 fitness[i] = self._evaluate_chromosome(mask, X_train, y_train, X_val, y_val)
#      79
#      80             # Track global best
#
# /content/CynolycusBot/Models/ga_xgboost/ga_xgboost.py in _evaluate_chromosome(self, mask, X_train, y_train, X_val, y_val)
#     186
#     187         model = XGBClassifier(**self.xgb_params)
# --> 188         model.fit(X_tr, y_train)
#     189         y_pred = model.predict(X_v)
#     190         # Assuming label 1 = “good swing / up move”
#
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     772             for k, arg in zip(sig.parameters, args):
#     773                 kwargs[k] = arg
# --> 774             return func(**kwargs)
#     775
#     776         return inner_f
#
# /usr/local/lib/python3.12/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1804             )
#    1805
# -> 1806             self._Booster = train(
#    1807                 params,
#    1808                 train_dmatrix,
#
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     772             for k, arg in zip(sig.parameters, args):
#     773                 kwargs[k] = arg
# --> 774             return func(**kwargs)
#     775
#     776         return inner_f
#
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     197         if cb_container.before_iteration(bst, i, dtrain, evals):
#     198             break
# --> 199         bst.update(dtrain, iteration=i, fobj=obj)
#     200         if cb_container.after_iteration(bst, i, dtrain, evals):
#     201             break
#
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    2432         if fobj is None:
#    2433             _check_call(
# -> 2434                 _LIB.XGBoosterUpdateOneIter(
#    2435                     self.handle, ctypes.c_int(iteration), dtrain.handle
#    2436                 )
#
# KeyboardInterrupt:

# %%
# %cd /content/CynolycusBot
# !git status
# !git add Data/models
# !git commit -m "Add GA-XGB model artifacts"
# !git push
# Out:
# /content/CynolycusBot
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (15/15), 55.88 KiB | 5.08 MiB/s, done.
# Total 15 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/ThompsonLuke7/CynolycusBot.git
#    92757bf..134b183  main -> main
