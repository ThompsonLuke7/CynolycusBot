# %%
# Clone repo into Colab VM (replace with your repo URL)
from getpass import getpass
token = getpass("GitHub token: ")
import os
if os.path.exists("/content/CynolycusBot/.git"):
    # %cd /content/CynolycusBot
    # !git pull
else:
    # !git clone https://{token}@github.com/ThompsonLuke7/CynolycusBot.git /content/CynolycusBot
    # %cd /content/CynolycusBot
    # !git remote set-url origin https://{token}@github.com/ThompsonLuke7/CynolycusBot.git

# !git config user.name "thompsonluke7"
# !git config user.email "lukethompson2203@gmail.com"
# Out:
# Cloning into '/content/CynolycusBot'...
# remote: Enumerating objects: 398, done.
# remote: Counting objects: 100% (398/398), done.
# remote: Compressing objects: 100% (260/260), done.
# remote: Total 398 (delta 166), reused 347 (delta 117), pack-reused 0 (from 0)
# Receiving objects: 100% (398/398), 20.81 MiB | 30.48 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not in a git directory
# fatal: not in a git directory

# %%
# %cd /content/CynolycusBot
# %run Models/ga_xgboost/ga_xgboost_two_models_test.py
# Out:
# /content/CynolycusBot
# Loaded train split: (920, 1224)
# Loaded test split:  (80, 1224)
#
# === LONG side ===
# LONG train positives: 75, negatives: 845, scale_pos_weight: 11.27
# [GA-XGB] Generation 1/30 - best val acc: 0.7500, global best: 0.7500
# [GA-XGB] Generation 2/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 3/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 4/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 5/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 6/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 7/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 8/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 9/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 10/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 11/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 12/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 13/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 14/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 15/30 - best val acc: 0.6000, global best: 0.8571
# [GA-XGB] Generation 16/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 17/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 18/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 19/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 20/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 21/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 22/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 23/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 24/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 25/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 26/30 - best val acc: 0.6667, global best: 0.8571
# [GA-XGB] Generation 27/30 - best val acc: 0.8571, global best: 0.8571
# [GA-XGB] Generation 28/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 29/30 - best val acc: 0.7500, global best: 0.8571
# [GA-XGB] Generation 30/30 - best val acc: 0.8571, global best: 0.8571
# LONG best GA val F1: 0.8571428571428571
# LONG selected features: 602
# LONG TEST F1 (class 1): 0.4286
# LONG TEST confusion matrix [[TN, FP], [FN, TP]]:
# [[69  4]
#  [ 4  3]]
#
# === SHORT side ===
# SHORT train positives: 76, negatives: 844, scale_pos_weight: 11.11
# [GA-XGB] Generation 1/30 - best val acc: 0.4706, global best: 0.4706
# [GA-XGB] Generation 2/30 - best val acc: 0.5333, global best: 0.5333
# [GA-XGB] Generation 3/30 - best val acc: 0.5000, global best: 0.5333
# [GA-XGB] Generation 4/30 - best val acc: 0.5333, global best: 0.5333
# [GA-XGB] Generation 5/30 - best val acc: 0.4211, global best: 0.5333
# [GA-XGB] Generation 6/30 - best val acc: 0.5333, global best: 0.5333
# [GA-XGB] Generation 7/30 - best val acc: 0.5714, global best: 0.5714
# [GA-XGB] Generation 8/30 - best val acc: 0.5882, global best: 0.5882
# [GA-XGB] Generation 9/30 - best val acc: 0.6667, global best: 0.6667
# [GA-XGB] Generation 10/30 - best val acc: 0.6154, global best: 0.6667
# [GA-XGB] Generation 11/30 - best val acc: 0.6154, global best: 0.6667
# [GA-XGB] Generation 12/30 - best val acc: 0.5556, global best: 0.6667
# [GA-XGB] Generation 13/30 - best val acc: 0.6154, global best: 0.6667
# [GA-XGB] Generation 14/30 - best val acc: 0.5333, global best: 0.6667
# [GA-XGB] Generation 15/30 - best val acc: 0.6154, global best: 0.6667
# [GA-XGB] Generation 16/30 - best val acc: 0.5333, global best: 0.6667
# [GA-XGB] Generation 17/30 - best val acc: 0.5000, global best: 0.6667
# [GA-XGB] Generation 18/30 - best val acc: 0.4706, global best: 0.6667
# [GA-XGB] Generation 19/30 - best val acc: 0.4444, global best: 0.6667
# [GA-XGB] Generation 20/30 - best val acc: 0.4615, global best: 0.6667
# [GA-XGB] Generation 21/30 - best val acc: 0.7500, global best: 0.7500
# [GA-XGB] Generation 22/30 - best val acc: 0.6667, global best: 0.7500
# [GA-XGB] Generation 23/30 - best val acc: 0.4706, global best: 0.7500
# [GA-XGB] Generation 24/30 - best val acc: 0.5333, global best: 0.7500
# [GA-XGB] Generation 25/30 - best val acc: 0.5714, global best: 0.7500
# [GA-XGB] Generation 26/30 - best val acc: 0.5000, global best: 0.7500
# [GA-XGB] Generation 27/30 - best val acc: 0.5714, global best: 0.7500
# [GA-XGB] Generation 28/30 - best val acc: 0.5333, global best: 0.7500
# [GA-XGB] Generation 29/30 - best val acc: 0.6000, global best: 0.7500
# [GA-XGB] Generation 30/30 - best val acc: 0.5714, global best: 0.7500
# SHORT best GA val F1: 0.75
# SHORT selected features: 624
# SHORT TEST F1 (class 1): 0.3077
# SHORT TEST confusion matrix [[TN, FP], [FN, TP]]:
# [[69  3]
#  [ 6  2]]
#
# Saved LONG artifacts to: /content/CynolycusBot/Data/models/ga_xgboost_two_models/long
# Saved SHORT artifacts to: /content/CynolycusBot/Data/models/ga_xgboost_two_models/short
#
# Latest bar predictions:
#   LONG model:  1 = good long swing, 0 = not: 0
#   SHORT model: 1 = good short swing, 0 = not: 0

# %%
# %cd /content/CynolycusBot
# !git status
# !git add Data/models
# !git commit -m "Add GA-XGB model artifacts"
# !git push
# Out:
# /content/CynolycusBot
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (15/15), 55.88 KiB | 5.08 MiB/s, done.
# Total 15 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/ThompsonLuke7/CynolycusBot.git
#    92757bf..134b183  main -> main
